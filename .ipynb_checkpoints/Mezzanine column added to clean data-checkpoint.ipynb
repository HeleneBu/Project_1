# %%
import pandas as pd

import numpy as np

from matplotlib import pyplot as plt

# %matplotlib inline

import seaborn as sns

df = pd.read_csv("clean_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0          id        date     price  bedrooms  bathrooms  \
# 0           0  7129300520  10/13/2014  221900.0         3       1.00
# 1           1  6414100192   12/9/2014  538000.0         3       2.25
# 2           2  5631500400   2/25/2015  180000.0         2       1.00
# 3           3  2487200875   12/9/2014  604000.0         4       3.00
# 4           4  1954400510   2/18/2015  510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  yr_built  yr_renovated  \
# 0         1180      5650     1.0         0.0  ...      1955           0.0
# 1         2570      7242     2.0         0.0  ...      1951        1991.0
# 2          770     10000     1.0         0.0  ...      1933           0.0
# 3         1960      5000     1.0         0.0  ...      1965           0.0
# 4         1680      8080     1.0         0.0  ...      1987           0.0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year_sold  age_house  \
# ...

# %%
df['floors'].dtype
# Out:
# dtype('float64')

# %%
df['floors'] = df['floors'].astype(str)

# %%
df.head()
# Out:
#    Unnamed: 0          id        date     price  bedrooms  bathrooms  \
# 0           0  7129300520  10/13/2014  221900.0         3       1.00
# 1           1  6414100192   12/9/2014  538000.0         3       2.25
# 2           2  5631500400   2/25/2015  180000.0         2       1.00
# 3           3  2487200875   12/9/2014  604000.0         4       3.00
# 4           4  1954400510   2/18/2015  510000.0         3       2.00
#
#    sqft_living  sqft_lot floors  waterfront  ...  yr_built  yr_renovated  \
# 0         1180      5650    1.0         0.0  ...      1955           0.0
# 1         2570      7242    2.0         0.0  ...      1951        1991.0
# 2          770     10000    1.0         0.0  ...      1933           0.0
# 3         1960      5000    1.0         0.0  ...      1965           0.0
# 4         1680      8080    1.0         0.0  ...      1987           0.0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year_sold  age_house  \
# ...

# %%
df['floors'].dtype
# Out:
# dtype('O')

# %%
df.floors.value_counts()
# Out:
# 1.0    10672
# 2.0     8235
# 1.5     1910
# 3.0      611
# 2.5      161
# 3.5        7
# Name: floors, dtype: int64

# %%
df['mezz'] = df[['floors']].applymap(lambda x: x[-1:])

# %%
df.head()
# Out:
#    Unnamed: 0          id        date     price  bedrooms  bathrooms  \
# 0           0  7129300520  10/13/2014  221900.0         3       1.00
# 1           1  6414100192   12/9/2014  538000.0         3       2.25
# 2           2  5631500400   2/25/2015  180000.0         2       1.00
# 3           3  2487200875   12/9/2014  604000.0         4       3.00
# 4           4  1954400510   2/18/2015  510000.0         3       2.00
#
#    sqft_living  sqft_lot floors  waterfront  ...  yr_renovated  zipcode  \
# 0         1180      5650    1.0         0.0  ...           0.0    98178
# 1         2570      7242    2.0         0.0  ...        1991.0    98125
# 2          770     10000    1.0         0.0  ...           0.0    98028
# 3         1960      5000    1.0         0.0  ...           0.0    98136
# 4         1680      8080    1.0         0.0  ...           0.0    98074
#
#        lat     long  sqft_living15  sqft_lot15  year_sold  age_house  \
# ...

# %%
df['mezz'].value_counts()
# Out:
# 0    19518
# 5     2078
# Name: mezz, dtype: int64

# %%
df.loc[df['mezz'] == 0, "mezzanine"] = "Yes"

# %%
df.head()
# Out:
#    Unnamed: 0          id        date     price  bedrooms  bathrooms  \
# 0           0  7129300520  10/13/2014  221900.0         3       1.00
# 1           1  6414100192   12/9/2014  538000.0         3       2.25
# 2           2  5631500400   2/25/2015  180000.0         2       1.00
# 3           3  2487200875   12/9/2014  604000.0         4       3.00
# 4           4  1954400510   2/18/2015  510000.0         3       2.00
#
#    sqft_living  sqft_lot floors  waterfront  ...  zipcode      lat     long  \
# 0         1180      5650    1.0         0.0  ...    98178  47.5112 -122.257
# 1         2570      7242    2.0         0.0  ...    98125  47.7210 -122.319
# 2          770     10000    1.0         0.0  ...    98028  47.7379 -122.233
# 3         1960      5000    1.0         0.0  ...    98136  47.5208 -122.393
# 4         1680      8080    1.0         0.0  ...    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15  year_sold  age_house  renovated  mezz  mezzanine
# ...

# %%
df['mezzanine'].value_counts()
# Out:
# Series([], Name: mezzanine, dtype: int64)
